# %% [markdown]
# agenda
#
# basics of python
#
#
# calculator
#
# library
#
# numpy,pandas,matplotlob,seaborn,sklearn,tensorflow,nltk
#
# container typee:list tuple,set,dictionary
#
# indexining and slicing
# membership operatior
#
# geeksforgeeks

# %%
print("Hello world")
# Out:
# Hello world

# %%
x=3
y=5
print(x*y)
print(x+y)
print(x-y)
print(x/y)
print(x**y)
x+=3
x-=3
# Out:
# 15
# 8
# -2
# 0.6
# 243

# %%
mylist =["Daawer","wasiullah","retesh","tessica"]
print(mylist[1:3])
type(mylist)
mylist.append("Rudra")
print(mylist)
print(mylist[0])
print(mylist[-1])
mylist[-1]= "jais"
print(mylist)
# Out:
# ['wasiullah', 'retesh']
# ['Daawer', 'wasiullah', 'retesh', 'tessica', 'Rudra']
# Daawer
# Rudra
# ['Daawer', 'wasiullah', 'retesh', 'tessica', 'jais']

# %%
myt =("Daawer","wasiullah","retesh","tessica")
type(myt)
# Out:
# tuple

# %%
myS = {"mango","pineapple","watermelon","mango","Mango"}
print(myS)
type(myS)
# Out:
# {'watermelon', 'Mango', 'pineapple', 'mango'}
# set

# %%
t= True
f = False
print(type(t))
print(type(f))
print(t or f)
print(t and f)
print(not f)
print(t != f)
# Out:
# <class 'bool'>
# <class 'bool'>
# True
# False
# True
# True

# %%
Var1= {"mango","banana","pineapple","Apple","apple","Apple","mango"}
Var2= {"Apple","banana","grapes","grapes","kiwi","kiwi","orange"}

# %%
#union of sets
Var1.union(Var2)
# Out:
# {'Apple', 'apple', 'banana', 'grapes', 'kiwi', 'mango', 'orange', 'pineapple'}

# %%
Var1.intersection(Var2)
# Out:
# {'Apple', 'banana'}

# %%
Var1.difference(Var2)
# Out:
# {'apple', 'mango', 'pineapple'}

# %%
Var2.difference(Var1)
# Out:
# {'grapes', 'kiwi', 'orange'}

# %%
Batsmen = ['kholi','Lara','Ponting','Gavaskar ','Dravid']

# %%
bowlers = ['Bhumra','Arshdeep','Shami','Archer','Siraj']

# %%
AllPlayers = Batsmen+bowlers

# %%
AllPlayers.remove("kholi")

# %%
#Dictionary
#pair
#key and value
WCwinners = {1975:"West Indies",
             1979:"West Indies",
             1983:"India",
             1987:"Australia",
             1991:"Pakistan",
             1996:"Srilanka",
             1999:"Australia",
             2003:"Australia",
               2007:"Australia",
             2011:"India"}

# %%
WCwinners[2023]="Australia"
WCwinners
# Out:
# {1975: 'West Indies',
#  1979: 'West Indies',
#  1983: 'India',
#  1987: 'Australia',
#  1991: 'Pakistan',
#  1996: 'Srilanka',
#  1999: 'Australia',
#  2003: 'Australia',
#  2007: 'Australia',
#  2011: 'India',
#  2023: 'Australia'}

# %%
AllPlayers.count("Shami")
# Out:
# 1

# %%
Var5 =("Ram","Shyam",[1,2,3,4,5],25,25.5)
Var5
# Out:
# ('Ram', 'Shyam', [1, 2, 3, 4, 5], 25, 25.5)

# %%
len(Var5)
# Out:
# 5

# %%
Var5[2][2]=40
Var5
# Out:
# ('Ram', 'Shyam', [1, 2, 40, 4, 5], 25, 25.5)

# %%
a= 20
b= 20.5
c= a+b
c
# Out:
# 40.5
