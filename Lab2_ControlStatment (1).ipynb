# %% [raw]
# ###control Statement
# if statemnet
# if-else stament
# if elif stament
#
# while loop
# for loop
#
# nested loop
#
# break
# continue
# pass stament

# %%
### indentation and if statment

# %%
### whether a number is positive or negative 

num = int(input("Enter your number"))
# Out:
# Enter your number 13

# %%
type(num)
# Out:
# int

# %%
num = int(input("Enter your number"))
if num>0:
print("The number is positive")
# Out:
#   Cell In[7], line 3
#     print("The number is positive")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
num>0
# Out:
# False

# %%
num = int(input("Enter your number"))
if num>0:
    print("The number is positive")
# Out:
# Enter your number 23
# The number is positive

# %%
num = int(input("Enter your number"))
if num>0:
    print("The number is positive")
else:
    print("The number is negative")
# Out:
# Enter your number -10
# The number is negative

# %%
#### your grades 

marks = int(input("Enter your marks"))

if marks<60:
    print("Your grade is F")
elif marks<70:
    print("Your grade is D")
elif marks<80:
    print("Your grade is C")
elif marks<90:
    print("Your grade is B")
elif marks<100:
    print("Your grade is A")
# Out:
# Enter your marks 23
# Your grade is F

# %%
### Nested if statement
num = int(input("Enter your number"))
if num>0:
    print("The number is positive")
    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")
elif num<0:
    print("The number is negative")
else:
    print("The number is Zero")
# Out:
# Enter your number 23
# The number is positive
# The number is odd

# %%
#### For loop 
mymarks = [86,89,77,78,76]

for mark in mymarks:
    print(mark)
# Out:
# 86
# 89
# 77
# 78
# 76

# %%
for mark in mymarks:
    print(mark*5)
# Out:
# 430
# 445
# 385
# 390
# 380

# %%
sum = 0
mymarks = [86,89,77,78,76]

for mark in mymarks:
    sum = sum+mark
print(sum)
# Out:
# 406

# %%
### enumerate 
students = ["Afifa","Saaketh","Karanveer","Asmit","Yurraj","Vardhan"]

for ind, stu in enumerate(students):
    print(ind,stu)
# Out:
# 0 Afifa
# 1 Saaketh
# 2 Karanveer
# 3 Asmit
# 4 Yurraj
# 5 Vardhan

# %%
name = "Durga Sharma"
for i in name:
    print(i)
# Out:
# D
# u
# r
# g
# a
#
# S
# h
# a
# r
# m
# a

# %%
### While loop 
count = 0
while count<5:
    print(count)
    count = count+1
print("The loop ends here ")
# Out:
# 0
# 1
# 2
# 3
# 4
# The loop ends here

# %%
### Break statment using loop 

for letters in "MachineLearning":
    if letters == "L":
        break
        
    print(letters)
print("This is break statment")
# Out:
# M
# a
# c
# h
# i
# n
# e
# This is break statment

# %%
for letters in "MachineLearning":
    if letters == "L":
        pass        
    print(letters)
print("This is pass statment")
# Out:
# M
# a
# c
# h
# i
# n
# e
# L
# e
# a
# r
# n
# i
# n
# g
# This is pass statment

# %%
for letters in "MachineLearning":
    if letters == "L":
        continue        
    print(letters)
print("This is continue statment")
# Out:
# M
# a
# c
# h
# i
# n
# e
# e
# a
# r
# n
# i
# n
# g
# This is continue statment

# %% [raw]
# nested loop, zip function, list comrehension, numpy

# %%
#Write a program to write multiplication table of given number

num = int(input("Enter the number "))
for i in range(1,11):
    result = num*i
    print(f"{num}X{i}  =  {result}")
# Out:
# Enter the number  67
# 67X1  =  67
# 67X2  =  134
# 67X3  =  201
# 67X4  =  268
# 67X5  =  335
# 67X6  =  402
# 67X7  =  469
# 67X8  =  536
# 67X9  =  603
# 67X10  =  670

# %%
#write the multiplication from 2 to 10 using nested loop
for num in range (2,11):
    print("Multiplication of ",num)
    print("..................................")
    for i in range(1,11):
        result = num*i
        print(f"{num} X {i} = {result}")
# Out:
# Multiplication of  2
# ..................................
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# 2 X 10 = 20
# Multiplication of  3
# ..................................
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
# 3 X 10 = 30
# Multiplication of  4
# ..................................
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
# 4 X 10 = 40
# Multiplication of  5
# ..................................
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50
# Multiplication of  6
# ..................................
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
# 6 X 10 = 60
# Multiplication of  7
# ...

# %%
### zip function 
players = ["Virat","Aiyer","Rajat","David","Kronel"]
Runs = [120,100,130, 199, 123]
Age = [32,33,35,25,28]
Todays_Score = [10,35,100,101,120]
Var_mapped = zip(players,Runs,Age,Todays_Score)
print(list(Var_mapped))
# Out:
# [('Virat', 120, 32, 10), ('Aiyer', 100, 33, 35), ('Rajat', 130, 35, 100), ('David', 199, 25, 101), ('Kronel', 123, 28, 120)]

# %%
#Var_mapped = list(Var_mapped)
P,R,A,T = zip(*Var_mapped)
print(P)
print(R)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 #Var_mapped = list(Var_mapped)
# ----> 2 P,R,A = zip(*Var_mapped)
#       3 print(P)
#
# ValueError: not enough values to unpack (expected 3, got 0)

# %%
pairs = [(1, 'a'), (2, 'b')]

# %%
type(Var_mapped)
# Out:
# zip

# %%
nums, chars = zip(*pairs)  # Unzips into two tuples
print(nums)   # (1, 2)
print(chars)  # ('a', 'b')
# Out:
# (1, 2)
# ('a', 'b')

# %%
marks = [23, 24,25,26,27]
for mark in marks:
    marks = mark+5
    print(marks)
# Out:
# 28
# 29
# 30
# 31
# 32

# %%
#2-d list 
All_planets = [["Mercury", "Venus","Earth"],["Mars","Jupiter","Saturn"],["Uranus","Neptune","Pluto"]]
All_planets
# Out:
# [['Mercury', 'Venus', 'Earth'],
#  ['Mars', 'Jupiter', 'Saturn'],
#  ['Uranus', 'Neptune', 'Pluto']]

# %%
single_list = []
for sublist in All_planets:
    for planet in sublist:
        if len(planet)>6:
            single_list.append(planet)
print(single_list)
# Out:
# ['Mercury', 'Jupiter', 'Neptune']

# %%
### single of code using list comprehension 
#var = [expression outer loop inner loop condition ]
singleList = [planet for sublist in All_planets for planet in sublist if len(planet)>6 ]
singleList
# Out:
# ['Mercury', 'Jupiter', 'Neptune']

# %%
marks = [23, 24,25,26,27]
print([x+2 for x in marks ])
# Out:
# [25, 26, 27, 28, 29]
